# %% [markdown]
# # Importing Python Libraries

# %%
# Installing libraries
# !pip install jupyter_bokeh
# !pip install hvplot
# Out:
# Requirement already satisfied: jupyter_bokeh in c:\users\danie\anaconda3\lib\site-packages (4.0.5)
# Requirement already satisfied: bokeh==3.* in c:\users\danie\anaconda3\lib\site-packages (from jupyter_bokeh) (3.4.1)
# Requirement already satisfied: ipywidgets==8.* in c:\users\danie\anaconda3\lib\site-packages (from jupyter_bokeh) (8.1.3)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\danie\anaconda3\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (3.1.4)
# Requirement already satisfied: contourpy>=1.2 in c:\users\danie\anaconda3\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (1.2.0)
# Requirement already satisfied: numpy>=1.16 in c:\users\danie\anaconda3\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (1.26.4)
# Requirement already satisfied: packaging>=16.8 in c:\users\danie\anaconda3\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (23.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\danie\anaconda3\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (2.2.2)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\danie\anaconda3\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (10.3.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\danie\anaconda3\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (6.0.1)
# Requirement already satisfied: tornado>=6.2 in c:\users\danie\anaconda3\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (6.4.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\danie\anaconda3\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (2022.9.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\danie\anaconda3\lib\site-packages (from ipywidgets==8.*->jupyter_bokeh) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\danie\anaconda3\lib\site-packages (from ipywidgets==8.*->jupyter_bokeh) (8.25.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\danie\anaconda3\lib\site-packages (from ipywidgets==8.*->jupyter_bokeh) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in c:\users\danie\anaconda3\lib\site-packages (from ipywidgets==8.*->jupyter_bokeh) (4.0.11)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in c:\users\danie\anaconda3\lib\site-packages (from ipywidgets==8.*->jupyter_bokeh) (3.0.11)
# Requirement already satisfied: decorator in c:\users\danie\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\danie\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\danie\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\danie\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\danie\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\danie\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.2.0)
# Requirement already satisfied: colorama in c:\users\danie\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\danie\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh==3.*->jupyter_bokeh) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\danie\anaconda3\lib\site-packages (from pandas>=1.2->bokeh==3.*->jupyter_bokeh) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\danie\anaconda3\lib\site-packages (from pandas>=1.2->bokeh==3.*->jupyter_bokeh) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\danie\anaconda3\lib\site-packages (from pandas>=1.2->bokeh==3.*->jupyter_bokeh) (2023.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\danie\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\danie\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\danie\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh==3.*->jupyter_bokeh) (1.16.0)
# Requirement already satisfied: executing in c:\users\danie\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\danie\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\danie\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.2.2)
# Requirement already satisfied: hvplot in c:\users\danie\anaconda3\lib\site-packages (0.10.0)
# Requirement already satisfied: bokeh>=1.0.0 in c:\users\danie\anaconda3\lib\site-packages (from hvplot) (3.4.1)
# Requirement already satisfied: colorcet>=2 in c:\users\danie\anaconda3\lib\site-packages (from hvplot) (3.1.0)
# Requirement already satisfied: holoviews>=1.11.0 in c:\users\danie\anaconda3\lib\site-packages (from hvplot) (1.19.0)
# Requirement already satisfied: numpy>=1.15 in c:\users\danie\anaconda3\lib\site-packages (from hvplot) (1.26.4)
# Requirement already satisfied: packaging in c:\users\danie\anaconda3\lib\site-packages (from hvplot) (23.2)
# Requirement already satisfied: pandas in c:\users\danie\anaconda3\lib\site-packages (from hvplot) (2.2.2)
# Requirement already satisfied: panel>=0.11.0 in c:\users\danie\anaconda3\lib\site-packages (from hvplot) (1.4.4)
# Requirement already satisfied: param<3.0,>=1.12.0 in c:\users\danie\anaconda3\lib\site-packages (from hvplot) (2.1.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\danie\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (3.1.4)
# Requirement already satisfied: contourpy>=1.2 in c:\users\danie\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (1.2.0)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\danie\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (10.3.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\danie\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (6.0.1)
# Requirement already satisfied: tornado>=6.2 in c:\users\danie\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (6.4.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\danie\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (2022.9.0)
# Requirement already satisfied: pyviz-comms>=2.1 in c:\users\danie\anaconda3\lib\site-packages (from holoviews>=1.11.0->hvplot) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\danie\anaconda3\lib\site-packages (from pandas->hvplot) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\danie\anaconda3\lib\site-packages (from pandas->hvplot) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\danie\anaconda3\lib\site-packages (from pandas->hvplot) (2023.3)
# Requirement already satisfied: markdown in c:\users\danie\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (3.4.1)
# Requirement already satisfied: markdown-it-py in c:\users\danie\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (2.2.0)
# Requirement already satisfied: linkify-it-py in c:\users\danie\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (2.0.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\danie\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (0.3.0)
# Requirement already satisfied: requests in c:\users\danie\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (2.32.2)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\danie\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (4.66.4)
# Requirement already satisfied: bleach in c:\users\danie\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (4.1.0)
# Requirement already satisfied: typing-extensions in c:\users\danie\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (4.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\danie\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh>=1.0.0->hvplot) (2.1.3)
# Requirement already satisfied: six>=1.5 in c:\users\danie\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->hvplot) (1.16.0)
# Requirement already satisfied: colorama in c:\users\danie\anaconda3\lib\site-packages (from tqdm>=4.48.0->panel>=0.11.0->hvplot) (0.4.6)
# Requirement already satisfied: webencodings in c:\users\danie\anaconda3\lib\site-packages (from bleach->panel>=0.11.0->hvplot) (0.5.1)
# Requirement already satisfied: uc-micro-py in c:\users\danie\anaconda3\lib\site-packages (from linkify-it-py->panel>=0.11.0->hvplot) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\danie\anaconda3\lib\site-packages (from markdown-it-py->panel>=0.11.0->hvplot) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\danie\anaconda3\lib\site-packages (from requests->panel>=0.11.0->hvplot) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\danie\anaconda3\lib\site-packages (from requests->panel>=0.11.0->hvplot) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\danie\anaconda3\lib\site-packages (from requests->panel>=0.11.0->hvplot) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\danie\anaconda3\lib\site-packages (from requests->panel>=0.11.0->hvplot) (2024.7.4)

# %%
# To get data from external files
import numpy as np
import pandas as pd
from io import BytesIO

# To plot the data
import matplotlib.pyplot as plt
import seaborn as sns
import panel as pn
pn.extension('tabulator')
import hvplot.pandas
import holoviews as hv
from bokeh.models import HoverTool

# To use basic math properties
import math
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='1c33733f-b863-489d-b1df-119eb00b945c'>
#   <div id="f23fbb83-9f65-41b1-bada-051c5f33218e" data-root-id="1c33733f-b863-489d-b1df-119eb00b945c" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"45fd0003-9da3-4bdc-8c05-ad5a2b148bb6":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"1c33733f-b863-489d-b1df-119eb00b945c"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"bcdf1e08-f354-49ee-a1b1-8bd5db866fd2","attributes":{"plot_id":"1c33733f-b863-489d-b1df-119eb00b945c","comm_id":"12aff44827c24b4eaebab903e4236e44","client_comm_id":"96d37918a6404a47965633a286dc597a"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"45fd0003-9da3-4bdc-8c05-ad5a2b148bb6","roots":{"1c33733f-b863-489d-b1df-119eb00b945c":"f23fbb83-9f65-41b1-bada-051c5f33218e"},"root_ids":["1c33733f-b863-489d-b1df-119eb00b945c"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root.Tabulator !== undefined) && ( root.Tabulator !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %% [markdown]
# # Importing and Filtering Data

# %%
default_data = pd.read_csv('Rainfall Datasets/default data.csv')
default_data.loc[default_data['RAINFALL']<0,'RAINFALL'] = 0

# %%
# Converting to Monthly Rainfall, milimeters to centimeters
data_m = default_data.groupby(['YEAR','MONTH'])['RAINFALL'].sum()/10
data_m_unstacked = data_m.unstack(level=0)

# Making data interactive
df_m = data_m_unstacked.interactive

# Plotting the Data
hover_tool = HoverTool(
    tooltips=[('Year','@columns'),
     ('Month','@index'),
      ('Rainfall','@value cm')]
)

plot_m = df_m.hvplot.heatmap(
    x='columns',
    y='index',
    title='Monthly Rainfall in centimeters',
    rot=70,
    xlabel='Year',
    ylabel='Month',
    width=600, height = 400).opts(
        tools=[hover_tool],
        invert_yaxis=True
    )

plot_m
# Out:
# <div id='8f12c24f-12b1-4e9a-b785-d8bee8906191'>
#   <div id="a4a74507-de0d-457c-88eb-53131899fccb" data-root-id="8f12c24f-12b1-4e9a-b785-d8bee8906191" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"f5cdf435-ee1d-4f7e-b09c-c244d08e0778":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"8f12c24f-12b1-4e9a-b785-d8bee8906191","attributes":{"name":"Row01158","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"00b0cc19-686e-4ac2-b93f-d4a7c5d0cdcb","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.4/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"7298d0f7-36f3-4cdb-8af1-79654ade7786","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.4/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"fd806581-c9cf-4b37-a5f1-017d77da0090","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.4/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"13451d5f-fac5-483b-8039-2e4ac9126905","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.4/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"Figure","id":"ad0857b6-b030-4327-968e-5f65563723a2","attributes":{"height":400,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"FactorRange","id":"4a78d885-8a04-4f0a-8a5c-1f2d840ddd2f","attributes":{"tags":[[["columns",null]],[]],"factors":["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019"]}},"y_range":{"type":"object","name":"Range1d","id":"6d93ca20-cfef-4781-8a6f-f53490407fb7","attributes":{"tags":[[["index",null]],{"type":"map","entries":[["invert_yaxis",true],["autorange",false]]}],"start":12.5,"end":0.5,"reset_start":12.5,"reset_end":0.5}},"x_scale":{"type":"object","name":"CategoricalScale","id":"5ba371c2-927c-4b88-b19a-73536a25f679"},"y_scale":{"type":"object","name":"LinearScale","id":"523c588b-811d-4522-865e-a4d113258766"},"title":{"type":"object","name":"Title","id":"b3d9e86b-bd8c-4258-ac6d-4b4443b7589a","attributes":{"text":"Monthly Rainfall in centimeters","text_color":"black","text_font_size":"12pt"}},"renderers":[{"type":"object","name":"GlyphRenderer","id":"9bad46ef-5363-433e-88a1-6806a06c0fb6","attributes":{"data_source":{"type":"object","name":"ColumnDataSource","id":"2e823c2d-9f2d-49bb-a508-58a3bedc5d62","attributes":{"selected":{"type":"object","name":"Selection","id":"af5b946d-3ed6-48c2-a622-73c8cd9cca84","attributes":{"indices":[],"line_indices":[]}},"selection_policy":{"type":"object","name":"UnionRenderers","id":"cc2ba8ba-632a-4456-971d-3be3f5ca686a"},"data":{"type":"map","entries":[["columns",["2000","2000","2000","2000","2000","2000","2000","2000","2000","2000","2000","2000","2001","2001","2001","2001","2001","2001","2001","2001","2001","2001","2001","2001","2002","2002","2002","2002","2002","2002","2002","2002","2002","2002","2002","2002","2003","2003","2003","2003","2003","2003","2003","2003","2003","2003","2003","2003","2004","2004","2004","2004","2004","2004","2004","2004","2004","2004","2004","2004","2005","2005","2005","2005","2005","2005","2005","2005","2005","2005","2005","2005","2006","2006","2006","2006","2006","2006","2006","2006","2006","2006","2006","2006","2007","2007","2007","2007","2007","2007","2007","2007","2007","2007","2007","2007","2008","2008","2008","2008","2008","2008","2008","2008","2008","2008","2008","2008","2009","2009","2009","2009","2009","2009","2009","2009","2009","2009","2009","2009","2010","2010","2010","2010","2010","2010","2010","2010","2010","2010","2010","2010","2011","2011","2011","2011","2011","2011","2011","2011","2011","2011","2011","2011","2012","2012","2012","2012","2012","2012","2012","2012","2012","2012","2012","2012","2013","2013","2013","2013","2013","2013","2013","2013","2013","2013","2013","2013","2014","2014","2014","2014","2014","2014","2014","2014","2014","2014","2014 ...

# %%
# Showing the Statistics per Year
print(data_m_unstacked.describe())
# Out:
# YEAR        2000       2001        2002      2003       2004       2005  \
# count  12.000000  12.000000   12.000000  12.00000  12.000000  12.000000
# mean   28.734167  15.268333   22.018333  17.01500  12.892500  13.256667
# std    26.408977  14.126444   41.090362  17.24522  12.998594  13.315806
# min     2.350000   2.630000    0.750000   0.12000   0.000000   0.000000
# 25%     4.930000   5.062500    1.437500   1.06750   3.067500   1.430000
# 50%    22.750000  10.505000    5.430000  11.37500  11.310000   7.365000
# 75%    45.737500  18.242500   22.872500  34.22500  18.630000  27.080000
# max    89.310000  46.540000  146.880000  42.55000  42.630000  32.880000
#
# YEAR        2006       2007       2008       2009       2010       2011  \
# count  12.000000  12.000000  12.000000  12.000000  12.000000  12.000000
# mean   17.460000  16.479167  18.330833  24.551667  16.351667  27.069167
# std    18.794844  19.077120  17.156368  26.126450  15.878930  26.289573
# min     0.000000   0.120000   1.990000   0.220000   0.000000   0.050000
# 25%     5.472500   2.780000   5.097500   5.220000   1.182500   7.435000
# 50%     9.290000   7.775000  12.645000  17.750000  13.150000  20.695000
# 75%    21.085000  23.145000  26.630000  32.727500  32.127500  36.517500
# max    56.930000  62.020000  54.730000  83.920000  36.210000  87.930000
#
# YEAR         2012        2013       2014       2015       2016       2017  \
# count   12.000000   12.000000  12.000000  12.000000  12.000000  12.000000
# mean    29.770000   25.820000  15.996667  17.210000  17.484167  19.376833
# std     34.447402   31.888625  16.670110  18.306458  20.704492  17.028248
# min      2.440000    1.150000   0.000000   0.240000   0.090000   0.580000
# 25%      5.480000    6.675000   1.690000   2.000000   4.857500   7.307500
# 50%     15.515000    9.460000  10.745000  13.125000   8.685000  14.550000
# 75%     41.885000   32.052500  32.817500  28.750000  25.455000  28.950250
# max    114.590000  105.670000  46.870000  55.310000  70.050000  51.961000
#
# YEAR        2018       2019
# count  12.000000  12.000000
# mean   20.895000  15.725000
# std    24.140051  17.463068
# min     0.150000   0.140000
# 25%     2.190000   0.415000
# 50%     9.115000  11.195000
# 75%    38.722500  27.395000
# max    62.620000  58.410000

# %%
# Converting to Annual Data, milimeters to meters
data_a = default_data.groupby('YEAR')['RAINFALL'].sum()/1000
rf_a = data_a.values
color_a = [{r==rf_a.min():'#85C1E9',
            rf_a.min()<r<rf_a.max():'#3498DB',
            r==rf_a.max():'#1F618D'}[True] for r in rf_a]

data_a = pd.DataFrame({'RAINFALL':data_a.values},index=data_a.index)
data_a['color'] = color_a
data_a['MEDIAN_DIFF'] = data_a['RAINFALL'] - \
  data_a['RAINFALL'].median()
data_a['color_diff'] = [{r<0:'red',0<=r:'green'}[True] for r
                        in data_a['MEDIAN_DIFF'].values]
data_a['MED_DIFF_C'] = data_a['MEDIAN_DIFF'].cumsum()
df_a = data_a.interactive

# %%
plot1_a = df_a.hvplot.bar(
    x='YEAR',
    y='RAINFALL',
    xlabel='Year',
    ylabel='',
    color='#3498DB',
    title='Rainfall per Year',
    width=700, height=500)

plot1_a
# Out:
# <div id='aa9db240-2671-42b0-b365-38c963b1dcb4'>
#   <div id="fffc8908-db52-4418-be11-9668dec27c24" data-root-id="aa9db240-2671-42b0-b365-38c963b1dcb4" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"d376bbbb-5b36-4097-ab15-539324fe3267":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"aa9db240-2671-42b0-b365-38c963b1dcb4","attributes":{"name":"Row01312","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"43eac53a-bd66-4bee-bc77-1661daaecd19","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.4/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"4340ba30-6eb5-44cc-99e3-85915362c81d","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.4/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"ce2c27bb-2e76-4c73-86ac-11c2d04a5586","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.4/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"faeb13f1-830b-4e4b-9c84-39f31e1bec25","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.4/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"Figure","id":"cec2278c-1dea-43db-b228-bba2b4ccdfb3","attributes":{"width":700,"height":500,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"Range1d","id":"4918f4a8-b58d-4330-82eb-fe917a86bcee","attributes":{"tags":[[["YEAR",null]],[]],"start":1998.642857142857,"end":2020.357142857143,"reset_start":1998.642857142857,"reset_end":2020.357142857143}},"y_range":{"type":"object","name":"Range1d","id":"659d6b5e-0a66-45ea-8f4a-e139e43b18d8","attributes":{"tags":[[["RAINFALL",null]],{"type":"map","entries":[["invert_yaxis",false],["autorange",false]]}],"end":3.77493,"reset_start":0.0,"reset_end":3.77493}},"x_scale":{"type":"object","name":"LinearScale","id":"77019d62-85d8-41aa-b28c-bf5237927a31"},"y_scale":{"type":"object","name":"LinearScale","id":"6f19dd60-64d9-4eca-803d-c6bcbb858bb8"},"title":{"type":"object","name":"Title","id":"d8b1e951-092d-46a9-a995-41b63424d1a4","attributes":{"text":"Rainfall per Year","text_color":"black","text_font_size":"12pt"}},"renderers":[{"type":"object","name":"GlyphRenderer","id":"f4f0efc5-4e08-4adb-99bd-1f4e14d0aec6","attributes":{"data_source":{"type":"object","name":"ColumnDataSource","id":"a4afc00a-346d-4158-9571-652466e9b01c","attributes":{"selected":{"type":"object","name":"Selection","id":"0bfbaa1b-8a1b-4ad7-80cb-2456f9c34686","attributes":{"indices":[],"line_indices":[]}},"selection_policy":{"type":"object","name":"UnionRenderers","id":"89f02c86-c786-4627-959d-52bdf5555e31"},"data":{"type":"map","entries":[["YEAR",{"type":"ndarray","array":{"type":"bytes","data":"0AcAANEHAADSBwAA0wcAANQHAADVBwAA1gcAANcHAADYBwAA2QcAANoHAADbBwAA3AcAAN0HAADeBwAA3wcAAOAHAADhBwAA4gcAAOMHAAA="},"shape":[20],"dtype":"int32","order":"little"}],["RAINFALL",{"type":"ndarray","array":{"type":"bytes","data":"Z7Pqc7WVC0D/snvysFD9P/rt68A5IwVAS8gHPZtVAED+Q/rt68D4P/mgZ7Pqc/k/M6K0N/jCAECkcD0K16P/P/AWSFD8mAFANc07TtGRB0ATYcPTK2X/Pz/G3LWE/AlA3NeBc0aUDEBFaW/whckIQPRsVn2utv4/9pfdk4eFAECb5h2n6MgAQHwKgPEMmgJAV+wvuycPBED+1HjpJjH+Pw=="},"shape":[20],"dtype":"float64","order":"little"}]]}}},"view":{"type":"object","name":"CDSView","id":"f5094b0f-dd2a-4797-8922-3e89b3ca7a70","attributes":{"filter":{"type":"object","name":"AllIndices","id":"ffb5c32c-4745-4e85-ad36-374a1d67f395"}}},"glyph":{"type":"object","name":"VBar","id":"e77cb5d2-be09-4a66-8ea4-0193d7020537","attributes":{"tags":["apply_ranges"],"x":{"type":"field","field":"YEAR"},"width":{"type":"value","value":0.8},"top":{"type":"field","field":"RAINFALL"},"fill_color":{"type":"value","value":"#3498DB"},"hatch_color":{"type":"value","value":"#3498DB"}}},"selection_glyph":{"type":"object","name":"VBar","id":"5d26549c-1ca8-48f4-8c25-b388299b706a","attributes":{"tags":["apply_ranges"],"x":{"type":"field","field":"YEAR"},"width":{"type":"value","value":0.8},"bottom":{"type":"value","value":0}, ...

# %%
hover_tool = HoverTool(
    tooltips=[('Year','@YEAR'),
     ('Rainfall','@RAINFALL m' )]
)

plot2_a = df_a.hvplot.bar(
    x='YEAR',
    y='RAINFALL',
    xlabel='Year',
    ylabel='',
    color='color',
    title='Rainfall per Year',
    width=700, height=500).opts(
        tools=[hover_tool]
    )

hline = hv.HLine(data_a['RAINFALL'].median()).opts(
        color='black',
        line_dash='dashed')
plot2_a * hline
# Out:
# <div id='58f6688b-8076-4c11-9c64-d20382082204'>
#   <div id="a27dd1a5-9d59-45b4-8cd4-a791a9b3d4e4" data-root-id="58f6688b-8076-4c11-9c64-d20382082204" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"9f12f6d6-f6a9-43cd-a3b2-cd47c9fce3de":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"58f6688b-8076-4c11-9c64-d20382082204","attributes":{"name":"Row01722","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"5cfbb4c4-19dc-435b-b7a1-bc1e4ab89e7e","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.4/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"a5028372-89c2-4fa4-8572-7ea27ed08491","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.4/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"84bfd81e-eab2-4e23-81e2-4af3a9631bf1","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.4/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"ef33581b-25d1-4096-abe4-329c65f4d9d2","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.4/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"Figure","id":"09d8f20d-5885-4946-99f9-92be7082524b","attributes":{"width":700,"height":500,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"Range1d","id":"997cac46-f73c-435e-8f99-5ac2a19ed82d","attributes":{"tags":[[["YEAR",null]],[]],"start":1998.642857142857,"end":2020.357142857143,"reset_start":1998.642857142857,"reset_end":2020.357142857143}},"y_range":{"type":"object","name":"Range1d","id":"eda34638-a4ac-491a-88f0-e30ed42e8972","attributes":{"tags":[[["RAINFALL",null]],{"type":"map","entries":[["invert_yaxis",false],["autorange",false]]}],"end":3.77493,"reset_start":0.0,"reset_end":3.77493}},"x_scale":{"type":"object","name":"LinearScale","id":"dd60af78-1232-4c76-966f-12c928c15e83"},"y_scale":{"type":"object","name":"LinearScale","id":"b3240c0c-5218-4528-82f3-52a3d4bc8384"},"title":{"type":"object","name":"Title","id":"fd703347-d28d-4abc-9162-ba6cb16c566c","attributes":{"text":"Rainfall per Year","text_color":"black","text_font_size":"12pt"}},"renderers":[{"type":"object","name":"GlyphRenderer","id":"03ff2bd5-2f8e-49ca-93ec-752919e0e6de","attributes":{"data_source":{"type":"object","name":"ColumnDataSource","id":"a4f76dfc-8128-47f8-9ac6-bef9cdaad3b9","attributes":{"selected":{"type":"object","name":"Selection","id":"cbad3f68-e864-4b78-b9c3-0dc81240c281","attributes":{"indices":[],"line_indices":[]}},"selection_policy":{"type":"object","name":"UnionRenderers","id":"b561b7d6-50ad-4fca-bade-72dc8caf5ef8"},"data":{"type":"map","entries":[["YEAR",{"type":"ndarray","array":{"type":"bytes","data":"0AcAANEHAADSBwAA0wcAANQHAADVBwAA1gcAANcHAADYBwAA2QcAANoHAADbBwAA3AcAAN0HAADeBwAA3wcAAOAHAADhBwAA4gcAAOMHAAA="},"shape":[20],"dtype":"int32","order":"little"}],["RAINFALL",{"type":"ndarray","array":{"type":"bytes","data":"Z7Pqc7WVC0D/snvysFD9P/rt68A5IwVAS8gHPZtVAED+Q/rt68D4P/mgZ7Pqc/k/M6K0N/jCAECkcD0K16P/P/AWSFD8mAFANc07TtGRB0ATYcPTK2X/Pz/G3LWE/AlA3NeBc0aUDEBFaW/whckIQPRsVn2utv4/9pfdk4eFAECb5h2n6MgAQHwKgPEMmgJAV+wvuycPBED+1HjpJjH+Pw=="},"shape":[20],"dtype":"float64","order":"little"}],["color",["#3498DB","#3498DB","#3498DB","#3498DB","#85C1E9","#3498DB","#3498DB","#3498DB","#3498DB","#3498DB","#3498DB","#3498DB","#1F618D","#3498DB","#3498DB","#3498DB","#3498DB","#3498DB","#3498DB","#3498DB"]]]}}},"view":{"type":"object","name":"CDSView","id":"f976f81e-5b9d-4a57-96f3-0e1fc76ba8f7","attributes":{"filter":{"type":"object","name":"AllIndices","id":"76127138-a170-4d8d-9e2f-6fe4572caf14"}}},"glyph":{"type":"object","name":"VBar","id":"236b8942-06d4-4882-b7f8-ccffaaf335a8","attributes":{"tags":["apply_ranges"],"x":{"type":"field","field":"YEAR"},"width":{"type":"value","value":0.8},"top":{"type":"field","field":"RAINFALL"},"fill_color":{"type":"field","field":"color"},"hatch_color":{"type":"field","field":"color"}}},"selection_glyph":{"type":"objec ...

# %%
hover_tool = HoverTool(
    tooltips=[('Year','@YEAR'),
     ('Difference to Median','@MEDIAN_DIFF{0.0000} m' )]
)

plot3_a = df_a.hvplot.bar(
    x='YEAR',
    y='MEDIAN_DIFF',
    xlabel='Year',
    ylabel='',
    color='color_diff',
    title='Difference to Median Rainfall',
    width=700, height=500).opts(
        tools=[hover_tool]
    )

hline = hv.HLine(0).opts(
        color='black')
plot3_a
# Out:
# <div id='e19be24d-02b8-4052-9932-74f398318f4d'>
#   <div id="bd7cda94-4795-4b66-9a6e-59aee0779aad" data-root-id="e19be24d-02b8-4052-9932-74f398318f4d" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"4bc6b147-e9d6-4ab1-84a3-09571ff9444e":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"e19be24d-02b8-4052-9932-74f398318f4d","attributes":{"name":"Row02035","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"0ded6cae-83ac-416d-ad72-4341f034cac3","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.4/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"db263c0c-6942-4748-bed8-83ede963f35f","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.4/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"d4ee325f-a58e-48e2-8f29-983b4143ed68","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.4/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"0407c770-e8f3-48dd-9c0d-9faa30239362","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.4/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"Figure","id":"d9643e8a-57d5-410b-ab2f-c970e9ecbe5f","attributes":{"width":700,"height":500,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"Range1d","id":"7ef616fb-da21-4f5b-bf0f-e41b6ea8b8e2","attributes":{"tags":[[["YEAR",null]],[]],"start":1998.642857142857,"end":2020.357142857143,"reset_start":1998.642857142857,"reset_end":2020.357142857143}},"y_range":{"type":"object","name":"Range1d","id":"dfe599d2-236e-4c29-9796-89ccbe0f0419","attributes":{"tags":[[["MEDIAN_DIFF",null]],{"type":"map","entries":[["invert_yaxis",false],["autorange",false]]}],"start":-0.75208,"end":1.6782800000000002,"reset_start":-0.75208,"reset_end":1.6782800000000002}},"x_scale":{"type":"object","name":"LinearScale","id":"fb36f471-5b11-4f33-ac6e-ec0e29c2e07a"},"y_scale":{"type":"object","name":"LinearScale","id":"6613313f-4b71-4548-9d63-cf2e73984071"},"title":{"type":"object","name":"Title","id":"c50a6143-8640-4bcb-924a-5bf14c4bdd38","attributes":{"text":"Difference to Median Rainfall","text_color":"black","text_font_size":"12pt"}},"renderers":[{"type":"object","name":"GlyphRenderer","id":"c539375c-f97b-4b89-b9b4-7305918630f4","attributes":{"data_source":{"type":"object","name":"ColumnDataSource","id":"c9f74746-2ef1-4aa5-aa50-57393dc12d7d","attributes":{"selected":{"type":"object","name":"Selection","id":"c4701175-722e-4eda-98d7-1cbd2f936acd","attributes":{"indices":[],"line_indices":[]}},"selection_policy":{"type":"object","name":"UnionRenderers","id":"c7f37c4f-cfc6-46bb-9aaf-0ae350bee014"},"data":{"type":"map","entries":[["YEAR",{"type":"ndarray","array":{"type":"bytes","data":"0AcAANEHAADSBwAA0wcAANQHAADVBwAA1gcAANcHAADYBwAA2QcAANoHAADbBwAA3AcAAN0HAADeBwAA3wcAAOAHAADhBwAA4gcAAOMHAAA="},"shape":[20],"dtype":"int32","order":"little"}],["MEDIAN_DIFF",{"type":"ndarray","array":{"type":"bytes","data":"AN4CCYqf9T88V1uxv+zQv0ymCkYldeE/AAdfmEwVrL+gibDh6ZXhv6rP1VbsL+C/AKARpb3BV7+gglFJnYC+vyBR2ht8Ybo/OCNKe4Mv6z/YPXlYqDXBv7AD54wobfI/6iYxCKyc9z+8SQwCKwfwP9De4AuTqca/QBzr4jYaoL8AoBGlvcFXP1BhbCHIQc0/gD81XrpJ2j+Ans2qz9XKvw=="},"shape":[20],"dtype":"float64","order":"little"}],["color_diff",["green","red","green","red","red","red","red","red","green","green","red","green","green","green","red","red","green","green","green","red"]],["color",["green","red","green","red","red","red","red","red","green","green","red","green","green","green","red","red","green","green","green","red"]]]}}},"view":{"type":"object","name":"CDSView","id":"34fbe25f-4f77-4adf-b442-b46f14e7e724","attributes":{"filter":{"type":"object","name":"AllIndices","id":"2c3e13e4-0ec5-4de4-9266-d6baa105e386"}}},"glyph":{"type":"object","name":"VBar","id":"21fc8743-af3d-4211-810d-f0195462fc12","attributes":{"tags":["apply_ranges"],"x":{"type":"field","field":"YEAR"},"width":{"type":"value","value":0.8},"top":{"ty ...

# %%
# Arranging the Rainfall Values in Increasing Order
rainfall_values = pd.DataFrame({'RAINFALL':default_data['RAINFALL'].values})
rainfall_values = rainfall_values.sort_values(by='RAINFALL',ignore_index=True)

# Getting the Plotting Position
rainfall_values['POSITION'] = list(range(1,rainfall_values.count().iloc[0]+1,1))\
/(rainfall_values.count().iloc[0]+1)

df = rainfall_values
idf = df.interactive
rf_stats = idf.hvplot.line(
    x='RAINFALL',
    y='POSITION',
    width=700,height=700
).opts(tools=['crosshair','hover'])

rf_stats
# Out:
# <div id='4e9e42ca-da1b-4dc6-9bb7-c6c4488e52c2'>
#   <div id="e02512ea-7021-4ed1-b9de-ef9d17cedde0" data-root-id="4e9e42ca-da1b-4dc6-9bb7-c6c4488e52c2" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"3d4d1eee-fef8-49ef-ab0f-b48df69940ac":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"4e9e42ca-da1b-4dc6-9bb7-c6c4488e52c2","attributes":{"name":"Row02292","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"8c67121b-1483-435c-ae45-1b5ccbe3dcc0","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.4/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"0fbb477f-f282-4e28-8944-3abd913f0e78","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.4/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"f291d6ca-1236-488b-89cc-ce94e3b98ca8","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.4/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"d42b6fe0-3833-4b7a-a95d-57f1950601fa","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.4/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"Figure","id":"68ce93c1-19db-4299-b98d-70b64269c0b7","attributes":{"width":700,"height":700,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"Range1d","id":"4503538e-09a4-49a8-b761-3beaebd33cc3","attributes":{"tags":[[["RAINFALL",null]],[]],"end":358.0,"reset_start":0.0,"reset_end":358.0}},"y_range":{"type":"object","name":"Range1d","id":"d855db49-0295-4de0-8a89-ea84529023ee","attributes":{"tags":[[["POSITION",null]],{"type":"map","entries":[["invert_yaxis",false],["autorange",false]]}],"start":-0.09983575143717492,"end":1.0998357514371748,"reset_start":-0.09983575143717492,"reset_end":1.0998357514371748}},"x_scale":{"type":"object","name":"LinearScale","id":"7ddbb5b5-8d9c-47bd-9f26-17efd506626a"},"y_scale":{"type":"object","name":"LinearScale","id":"20328505-ba63-4b56-ba0a-0742b798cfff"},"title":{"type":"object","name":"Title","id":"a51555ab-39f5-4108-bcf3-7c37d2d3b9c9","attributes":{"text_color":"black","text_font_size":"12pt"}},"renderers":[{"type":"object","name":"GlyphRenderer","id":"bf5c45c7-bc5c-4ca8-9ce9-bfe28b1aab79","attributes":{"data_source":{"type":"object","name":"ColumnDataSource","id":"08e76155-232b-41d4-84d9-8167d8f1841b","attributes":{"selected":{"type":"object","name":"Selection","id":"8793f758-e0f2-4745-bafb-d6fb40f5f928","attributes":{"indices":[],"line_indices":[]}},"selection_policy":{"type":"object","name":"UnionRenderers","id":"b6fa65e0-994d-47e6-9e3c-7c64d924f61a"},"data":{"type":"map","entries":[["RAINFALL",{"type":"ndarray","array":{"type":"bytes","data":"..."},"shape":[7305],"dtype":"float64","order":"little"}],["POSITION",{"type":"ndarray","array":{"type":"bytes","data":"..."},"shape":[7305],"dtype":"float64","order":"little"}]]}}},"view":{"type":"object","name":"CDSView","id":"9d71bbb9-f502-4bd1-9f5d-fb8bfc62b8cc","attributes":{"filter":{"type":"object","name":"AllIndices","id":"6538e28b-e4ee-47fe-97af-c356d09dfc31"}}},"glyph":{"type":"object","name":"Line","id":"1fb6f90e-d64e-4a63-8997-6d1ff70ce7cd","attributes":{"tags":["apply_ranges"],"x":{"type":"field","field":"RAINFALL"},"y":{"type":"field","field":"POSITION"},"line_color":"#30a2da","line_width":2}},"selection_glyph":{"type":"object","name":"Line","id":"594c8fff-7666-4306-84e0-899fbf3dfc63","attributes":{"tags":["apply_ranges"],"x":{"type":"field","field":"RAINFALL"},"y":{"type":"field","field":"POSITION"},"line_color":"#30a2da","line_width":2}},"nonselection_glyph":{"type":"object","name":"Line","id":"ebde9777-301a-4584-84c2-4e5baae9c872","attributes":{"tags":["apply_ranges"],"x":{"type":"field","field":"RAINFALL"},"y":{"type":"field","field":"POSITION"},"line_color":"#30a2da","line_alpha":0.1,"line_width":2}},"muted_glyph":{"type":"object","name":"Line","id":"2f3cba67-62bf-4dc4-85bc-6154cefa4027","attributes":{"tags":["apply_ranges"],"x":{"type": ...

# %% [markdown]
# # Dashboard Components

# %%
file_input = pn.widgets.FileInput(accept='.csv',multiple=False)

# %%
submit = pn.widgets.Button(name='Submit', button_type='primary')

# %% [markdown]
# # Dashboard Interactivity

# %%
def submit_file(clicked):
    if clicked:
        return pd.read_csv(BytesIO(file_input.value))
    return  pd.read_csv('Rainfall Datasets/default data.csv')
    
uploaded_data = pn.bind(submit_file,submit)

# %%
def clean_data(dataset):
    dataset.loc[dataset['RAINFALL']<0,'RAINFALL'] = 0
    return dataset
    
cleaned_data = pn.bind(clean_data, uploaded_data)

# %%
def convert_to_year(dataset):
    data_a = dataset.groupby('YEAR')['RAINFALL'].sum()/1000
    
    rf_a = data_a.values
    color_a = [{r==rf_a.min():'#85C1E9',
                rf_a.min()<r<rf_a.max():'#3498DB',
                r==rf_a.max():'#1F618D'}[True] for r in rf_a]
    
    data_a = pd.DataFrame({'RAINFALL':data_a.values},index=data_a.index)
    data_a['color'] = color_a
    
    data_a['MEDIAN_DIFF'] = data_a['RAINFALL'] - \
      data_a['RAINFALL'].median()
    data_a['color_diff'] = [{r<0:'red',0<=r:'green'}[True] for r
                            in data_a['MEDIAN_DIFF'].values]
    data_a['MED_DIFF_C'] = data_a['MEDIAN_DIFF'].cumsum()
    return data_a
    
yearly_data = pn.bind(convert_to_year, cleaned_data)

# %%
table = pn.widgets.StaticText(value=uploaded_data)
table2 = pn.widgets.StaticText(value=cleaned_data)

# %% [markdown]
# # Creating the Dashboard

# %%
template = pn.template.FastListTemplate(
     title='Rainfall Analysis',
     sidebar=[
         pn.pane.Markdown("## Upload Data:"),
         file_input,
         submit,
     ],
     main=[
         table,
         pn.widgets.StaticText(value="test"),
         table2,
         pn.pane.Markdown("# Yearly Rainfall Trend"),
         
         pn.pane.Markdown("# Monthly Rainfall Trend"),
         
         pn.pane.Markdown("# Daily Rainfall Percentile"),

          ]
)
template.servable();
